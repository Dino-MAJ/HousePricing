# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("housing.csv")

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data.dropna(inplace=True)

# %%
data.info
# Out:
# <bound method DataFrame.info of        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20433 rows x 10 columns]>

# %%
from sklearn.model_selection import train_test_split

X = data.drop(['median_house_value'], axis = 1)
y = data["median_house_value"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
train_data = X_train.join(y_train)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12686    -121.48     38.59                43.0        987.0           240.0
# 15079    -116.97     32.81                19.0       1573.0           471.0
# 3351     -121.02     40.51                17.0        890.0           167.0
# 16165    -122.50     37.77                52.0       2739.0           569.0
# 10298    -117.85     33.92                11.0       3331.0           410.0
# ...          ...       ...                 ...          ...             ...
# 19909    -119.30     36.33                44.0       2060.0           414.0
# 10363    -117.69     33.62                18.0       4265.0           581.0
# 12389    -116.43     33.75                24.0       2596.0           438.0
# 15657    -122.41     37.79                52.0       6016.0          2509.0
# 12429    -116.25     33.68                16.0        926.0           189.0
#
#        population  households  median_income ocean_proximity  \
# 12686      1253.0       237.0         0.9204          INLAND
# 15079       844.0       414.0         2.1422       <1H OCEAN
# 3351        406.0       154.0         3.3036          INLAND
# 16165      1312.0       531.0         3.5833        NEAR BAY
# 10298      1460.0       416.0         8.0287       <1H OCEAN
# ...           ...         ...            ...             ...
# 19909       819.0       355.0         2.8795          INLAND
# 10363      2025.0       544.0         6.4598       <1H OCEAN
# 12389       473.0       237.0         3.7727          INLAND
# 15657      3436.0      2119.0         2.5166        NEAR BAY
# 12429       238.0       118.0         3.0114          INLAND
#
#        median_house_value
# 12686             82100.0
# 15079            125000.0
# 3351              78300.0
# 16165            322900.0
# 10298            371800.0
# ...                   ...
# 19909             77000.0
# 10363            282700.0
# 12389            500001.0
# 15657            275000.0
# 12429            366700.0
#
# [16346 rows x 10 columns]

# %%
train_data.hist(figsize=(15, 8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data.corr(numeric_only=True)
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924224           -0.106372     0.041019
# latitude            -0.924224  1.000000            0.011130    -0.034260
# housing_median_age  -0.106372  0.011130            1.000000    -0.362113
# total_rooms          0.041019 -0.034260           -0.362113     1.000000
# total_bedrooms       0.064955 -0.064436           -0.324791     0.930810
# population           0.093243 -0.104348           -0.300257     0.869060
# households           0.052024 -0.069546           -0.305381     0.920215
# median_income       -0.015418 -0.079966           -0.119241     0.202674
# median_house_value  -0.041508 -0.147286            0.101950     0.136457
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.064955    0.093243    0.052024      -0.015418
# latitude                 -0.064436   -0.104348   -0.069546      -0.079966
# housing_median_age       -0.324791   -0.300257   -0.305381      -0.119241
# total_rooms               0.930810    0.869060    0.920215       0.202674
# total_bedrooms            1.000000    0.889821    0.980436      -0.001197
# population                0.889821    1.000000    0.917502       0.012556
# households                0.980436    0.917502    1.000000       0.019080
# median_income            -0.001197    0.012556    0.019080       1.000000
# median_house_value        0.053873   -0.021024    0.067822       0.689221
#
#                     median_house_value
# longitude                    -0.041508
# latitude                     -0.147286
# housing_median_age            0.101950
# total_rooms                   0.136457
# total_bedrooms                0.053873
# population                   -0.021024
# households                    0.067822
# median_income                 0.689221
# median_house_value            1.000000

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(numeric_only=True), annot = True, cmap = "YlGnBu")
# Out:
# <Axes: >

# %%
# Normalizing these four features
train_data["total_rooms"] = np.log(train_data["total_rooms"] + 1)
train_data["total_bedrooms"] = np.log(train_data["total_bedrooms"] + 1)
train_data["population"] = np.log(train_data["population"] + 1)
train_data["total_rooms"] = np.log(train_data["households"] + 1)

# %%
train_data.hist(figsize=(15, 8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data.ocean_proximity.value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     7210
# INLAND        5254
# NEAR OCEAN    2079
# NEAR BAY      1800
# ISLAND           3
# Name: count, dtype: int64

# %%
#One-Hot encoding for ocean proximity
pd.get_dummies(train_data.ocean_proximity)
# Out:
#        <1H OCEAN  INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 12686      False    True   False     False       False
# 15079       True   False   False     False       False
# 3351       False    True   False     False       False
# 16165      False   False   False      True       False
# 10298       True   False   False     False       False
# ...          ...     ...     ...       ...         ...
# 19909      False    True   False     False       False
# 10363       True   False   False     False       False
# 12389      False    True   False     False       False
# 15657      False   False   False      True       False
# 12429      False    True   False     False       False
#
# [16346 rows x 5 columns]

# %%
train_data = train_data.join(pd.get_dummies(train_data.ocean_proximity)).drop(["ocean_proximity"], axis = 1)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12686    -121.48     38.59                43.0     5.472271        5.484797
# 15079    -116.97     32.81                19.0     6.028279        6.156979
# 3351     -121.02     40.51                17.0     5.043425        5.123964
# 16165    -122.50     37.77                52.0     6.276643        6.345636
# 10298    -117.85     33.92                11.0     6.033086        6.018593
# ...          ...       ...                 ...          ...             ...
# 19909    -119.30     36.33                44.0     5.874931        6.028279
# 10363    -117.69     33.62                18.0     6.300786        6.366470
# 12389    -116.43     33.75                24.0     5.472271        6.084499
# 15657    -122.41     37.79                52.0     7.659171        7.828038
# 12429    -116.25     33.68                16.0     4.779123        5.247024
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 12686    7.134094       237.0         0.9204             82100.0      False
# 15079    6.739337       414.0         2.1422            125000.0       True
# 3351     6.008813       154.0         3.3036             78300.0      False
# 16165    7.180070       531.0         3.5833            322900.0      False
# 10298    7.286876       416.0         8.0287            371800.0       True
# ...           ...         ...            ...                 ...        ...
# 19909    6.709304       355.0         2.8795             77000.0      False
# 10363    7.613819       544.0         6.4598            282700.0       True
# 12389    6.161207       237.0         3.7727            500001.0      False
# 15657    8.142354      2119.0         2.5166            275000.0      False
# 12429    5.476464       118.0         3.0114            366700.0      False
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 12686    True   False     False       False
# 15079   False   False     False       False
# 3351     True   False     False       False
# 16165   False   False      True       False
# 10298   False   False     False       False
# ...       ...     ...       ...         ...
# 19909    True   False     False       False
# 10363   False   False     False       False
# 12389    True   False     False       False
# 15657   False   False      True       False
# 12429    True   False     False       False
#
# [16346 rows x 14 columns]

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(numeric_only=True), annot = True, cmap = "YlGnBu")
# Out:
# <Axes: >

# %%
# Can easily distinguish what factors cause what houses to increase in price
# For example, near ocean means higher price, while latitude doesn't really help
# determine the price of a house

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x="latitude", y="longitude", data = train_data, hue = "median_house_value", palette="coolwarm")
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
# Making new features to train on
train_data["bedroom_ratio"] = train_data["total_bedrooms"]/train_data["total_rooms"]
train_data["household_rooms"] = train_data["total_rooms"]/train_data["households"]

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(numeric_only=True), annot = True, cmap = "YlGnBu")
# Out:
# <Axes: >

# %%
# Linear Regression Model
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
#Need to recategroize the data as we added two new feature variables, but the splot can stay the same

X_train, y_train = train_data.drop(["median_house_value"], axis = 1), train_data["median_house_value"]
X_train_s = scaler.fit_transform(X_train)
reg = LinearRegression()
reg.fit(X_train_s, y_train)
# Out:
# LinearRegression()

# %%
# Need to add all the test_data together and make all the changes we did before because
# We split up the data set tp early before making all of our feature changes
test_data = X_test.join(y_test)

test_data["total_rooms"] = np.log(test_data["total_rooms"] + 1)
test_data["total_bedrooms"] = np.log(test_data["total_bedrooms"] + 1)
test_data["population"] = np.log(test_data["population"] + 1)
test_data["total_rooms"] = np.log(test_data["households"] + 1)

test_data = test_data.join(pd.get_dummies(test_data.ocean_proximity)).drop(["ocean_proximity"], axis = 1)

test_data["bedroom_ratio"] = test_data["total_bedrooms"]/test_data["total_rooms"]
test_data["household_rooms"] = test_data["total_rooms"]/test_data["households"]

# %%
X_test, y_test = test_data.drop(["median_house_value"], axis=1), test_data["median_house_value"]

# %%
#One thing to look out for is that the island is a rare occurence, so if the island by
#Random chance is not in the test_data, it would have different dimensions then the 
#train data, which may cause problems
test_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 762      -122.08     37.65                35.0     5.926926        5.976351
# 4283     -118.32     34.09                34.0     6.483107        6.516193
# 2872     -118.95     35.37                37.0     5.690359        5.793014
# 5534     -118.43     33.96                38.0     5.099866        5.379897
# 11871    -117.35     34.00                38.0     5.468060        5.541264
# ...          ...       ...                 ...          ...             ...
# 12256    -116.98     33.83                15.0     5.860786        6.159095
# 13715    -117.17     34.12                 3.0     7.560601        7.718241
# 5432     -118.41     34.02                19.0     7.196687        7.295056
# 12265    -116.88     33.74                20.0     6.232448        6.436150
# 11283    -117.96     33.79                29.0     6.180017        6.218600
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 762      6.997596       374.0         3.6818            165400.0      False
# 4283     7.589336       653.0         2.0557            225000.0       True
# 2872     6.853299       295.0         1.6728             55400.0      False
# 5534     6.030685       163.0         6.1985            422000.0       True
# 11871    6.584791       236.0         2.5469             87800.0      False
# ...           ...         ...            ...                 ...        ...
# 12256    6.483107       350.0         2.6830            139300.0      False
# 13715    8.712924      1920.0         6.2178            173900.0      False
# 5432     7.877397      1334.0         3.3955            225000.0       True
# 12265    6.908755       508.0         1.5982            140000.0      False
# 11283    7.065613       482.0         2.0677            214500.0       True
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN  bedroom_ratio  household_rooms
# 762     False   False      True       False       1.008339         0.015847
# 4283    False   False     False       False       1.005103         0.009928
# 2872     True   False     False       False       1.018040         0.019289
# 5534    False   False     False       False       1.054909         0.031288
# 11871    True   False     False       False       1.013387         0.023170
# ...       ...     ...       ...         ...            ...              ...
# 12256    True   False     False       False       1.050899         0.016745
# 13715    True   False     False       False       1.020850         0.003938
# 5432    False   False     False       False       1.013669         0.005395
# 12265    True   False     False       False       1.032684         0.012269
# 11283   False   False     False       False       1.006243         0.012822
#
# [4087 rows x 16 columns]

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12686    -121.48     38.59                43.0     5.472271        5.484797
# 15079    -116.97     32.81                19.0     6.028279        6.156979
# 3351     -121.02     40.51                17.0     5.043425        5.123964
# 16165    -122.50     37.77                52.0     6.276643        6.345636
# 10298    -117.85     33.92                11.0     6.033086        6.018593
# ...          ...       ...                 ...          ...             ...
# 19909    -119.30     36.33                44.0     5.874931        6.028279
# 10363    -117.69     33.62                18.0     6.300786        6.366470
# 12389    -116.43     33.75                24.0     5.472271        6.084499
# 15657    -122.41     37.79                52.0     7.659171        7.828038
# 12429    -116.25     33.68                16.0     4.779123        5.247024
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 12686    7.134094       237.0         0.9204             82100.0      False
# 15079    6.739337       414.0         2.1422            125000.0       True
# 3351     6.008813       154.0         3.3036             78300.0      False
# 16165    7.180070       531.0         3.5833            322900.0      False
# 10298    7.286876       416.0         8.0287            371800.0       True
# ...           ...         ...            ...                 ...        ...
# 19909    6.709304       355.0         2.8795             77000.0      False
# 10363    7.613819       544.0         6.4598            282700.0       True
# 12389    6.161207       237.0         3.7727            500001.0      False
# 15657    8.142354      2119.0         2.5166            275000.0      False
# 12429    5.476464       118.0         3.0114            366700.0      False
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN  bedroom_ratio  household_rooms
# 12686    True   False     False       False       1.002289         0.023090
# 15079   False   False     False       False       1.021349         0.014561
# 3351     True   False     False       False       1.015969         0.032750
# 16165   False   False      True       False       1.010992         0.011820
# 10298   False   False     False       False       0.997598         0.014503
# ...       ...     ...       ...         ...            ...              ...
# 19909    True   False     False       False       1.026102         0.016549
# 10363   False   False     False       False       1.010425         0.011582
# 12389    True   False     False       False       1.111878         0.023090
# 15657   False   False      True       False       1.022048         0.003615
# 12429    True   False     False       False       1.097905         0.040501
#
# [16346 rows x 16 columns]

# %%
X_test_s = scaler.transform(X_test)

# %%
reg.score(X_test_s, y_test)
# Out:
# 0.6661143640220245

# %%
# Random Forest Mode, will also do hyperparameters tuning
from sklearn.ensemble import RandomForestRegressor

forest = RandomForestRegressor()

forest.fit(X_train_s, y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(X_test_s, y_test)
# Out:
# 0.8126213759011515

# %%
# Cross validation is we split in into k-folds, and have 10 dif. k-folds, nine are used
# For training while 1 is used for test, and the program runs through all possible 
# Combinations of those hyperparameters and spits out the best result
from sklearn.model_selection import GridSearchCV

forest  = RandomForestRegressor() #Defining a fresh one so we don't have fitted version from above
# Change the features to be a little higher and add new ones to try for better hyperparameters
param_grid = {
    "n_estimators": [100, 200, 300],
    "max_depth": [None, 4, 8],
    "min_samples_split": [2, 4]
}
grid_search = GridSearchCV(forest, param_grid, cv=5,
                           scoring = "neg_mean_squared_error",
                           return_train_score=True)
grid_search.fit(X_train_s, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [None, 4, 8], 'min_samples_split': [2, 4],
#                          'n_estimators': [100, 200, 300]},
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
best_forest = grid_search.best_estimator_

# %%
best_forest.score(X_test_s, y_test)
# Out:
# 0.8156877370441243

# %%
# Improved slightly!

# %%
import tensorflow as tf
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 import tensorflow as tf
#
# ModuleNotFoundError: No module named 'tensorflow'
